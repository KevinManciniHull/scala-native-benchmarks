# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (20.0, 15.0)

# %%
rawpoints = []
conf      = "jvm"
bench     = "rep.RepBenchmark"
run       = 1
with open("../results/{}/{}/{}".format(conf, bench, run)) as data:
    for line in data.readlines():
        rawpoints.append(float(line)/1000000)
raw = np.array(rawpoints)
filtered = []
pmax = np.percentile(raw, 99)
for point in rawpoints:
    if point < pmax:
        filtered.append(point)
y = np.array(filtered)

# %%
len(y)
# Out:
# 495

# %%
#plt.axis([0, len(y), 0.5, 5])
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.plot(y)
plt.xlabel("Execution's number",fontsize=24)
plt.ylabel("Execution time (seconds)",fontsize=24)
# Out:
# Text(0, 0.5, 'Execution time (seconds)')

# %%
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.hist(y[:200], bins = 10)
plt.xlabel("Execution time (seconds)",fontsize=24)
plt.ylabel("Time repetitions",fontsize=24)
# Out:
# Text(0, 0.5, 'Time repetitions')

# %%
percentiles = np.arange(0, 100)
percvalue = np.array([np.percentile(y[:500], perc) for perc in percentiles])
plt.plot(percentiles, percvalue)

# %%
np.percentile(y, 5)
# Out:
# 22.4653716

# %%
np.percentile(y, 50)
# Out:
# 25.497117

# %%
np.percentile(y, 95)
# Out:
# 32.130927799999995

# %%
np.mean(y)
# Out:
# 26.131316694949497

# %%
y.std()
# Out:
# 3.161865353333346
